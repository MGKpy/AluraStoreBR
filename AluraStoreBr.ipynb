# %% [markdown]
# <a href="https://colab.research.google.com/github/MGKpy/AluraStoreBR/blob/main/AluraStoreBr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Importação dos dados**

# %%
import pandas as pd

loja_1 = pd.read_csv('loja_1.csv')
loja_2 = pd.read_csv('loja_2.csv')
loja_3 = pd.read_csv('loja_3.csv')
loja_4 = pd.read_csv('loja_4.csv')

loja_1 = pd.DataFrame(loja_1)
loja_2 = pd.DataFrame(loja_2)
loja_3 = pd.DataFrame(loja_3)
loja_4 = pd.DataFrame(loja_4)

# %%
loja_1
# Out:
#                     Produto Categoria do Produto    Preço      Frete  \
# 0        Assistente virtual          eletronicos   219.08   9.249790
# 1            Mesa de jantar               moveis   256.35  11.234305
# 2         Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3               Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4     Cadeira de escritório               moveis   446.99  26.964689
# ...                     ...                  ...      ...        ...
# 2354       Celular Plus X42          eletronicos  1712.54  88.772042
# 2355             Impressora          eletronicos   377.02  20.363958
# 2356      Jogo de tabuleiro           brinquedos   163.82   9.611337
# 2357               Cama box               moveis   921.77  46.665919
# 2358             Smartwatch          eletronicos   259.95  11.425995
#
#      Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# ...

# %% [markdown]
# # 1. Análise do faturamento

# %%
faturamento_total_loja1 = round(loja_1['Preço'].sum())
faturamento_total_loja2 = round(loja_2['Preço'].sum())
faturamento_total_loja3 = round(loja_3['Preço'].sum())
faturamento_total_loja4 = round(loja_4['Preço'].sum())
print(f'Faturamento das lojas:\nloja 1: {faturamento_total_loja1}\nloja 2: {faturamento_total_loja2}\nloja 3: {faturamento_total_loja3}\nloja 4: {faturamento_total_loja4}')
# Out:
# Faturamento das lojas:
# loja 1: 1534509
# loja 2: 1488459
# loja 3: 1464025
# loja 4: 1384498

# %%
import plotly.express as px
df_faturamento = { "Loja":["Loja 1","Loja 2", "Loja 3", "Loja 4"],
      "Faturamento":[faturamento_total_loja1,faturamento_total_loja2,faturamento_total_loja3,faturamento_total_loja4]}
df = pd.DataFrame(df_faturamento)
fig = px.bar(data_frame=df,
             x="Loja",
             y='Faturamento',
             title="Faturamento por loja",
             color="Loja",
             text="Faturamento")

# Ajustar formatação (opcional)
fig.update_traces(texttemplate='R$ %{text:,.2f}', textposition='outside')  # Formato monetário
fig.update_layout(yaxis_title="Faturamento (R$)")  # Renomear eixo Y

# Mostrar o gráfico
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # 2. Vendas por Categoria

# %%
categoria_preço1 = loja_1[['Categoria do Produto', 'Preço']]
total_por_Categoria1 = categoria_preço1.groupby('Categoria do Produto')['Preço'].sum().reset_index()
total_por_Categoria1 = pd.DataFrame(total_por_Categoria1)
total_por_Categoria1['Preço'] = round(total_por_Categoria1['Preço'])

categoria_preço2 = loja_2[['Categoria do Produto', 'Preço']]
total_por_Categoria2 = categoria_preço2.groupby('Categoria do Produto')['Preço'].sum().reset_index()
total_por_Categoria2 = pd.DataFrame(total_por_Categoria2)
total_por_Categoria2['Preço'] = round(total_por_Categoria2['Preço'])

categoria_preço3 = loja_3[['Categoria do Produto', 'Preço']]
total_por_Categoria3 = categoria_preço3.groupby('Categoria do Produto')['Preço'].sum().reset_index()
total_por_Categoria3 = pd.DataFrame(total_por_Categoria3)
total_por_Categoria3['Preço'] = round(total_por_Categoria3['Preço'])

categoria_preço4 = loja_4[['Categoria do Produto', 'Preço']]
total_por_Categoria4 = categoria_preço4.groupby('Categoria do Produto')['Preço'].sum().reset_index()
total_por_Categoria4 = pd.DataFrame(total_por_Categoria4)
total_por_Categoria4['Preço'] = round(total_por_Categoria4['Preço'])

# %%
from re import sub
import plotly.graph_objects as go
from plotly.subplots import make_subplots

def subplots(dataframe1, dataframe2, dataframe3, dataframe4):
    fig_subplot = make_subplots(
    rows = 2,
    cols = 2,
    subplot_titles=("Loja 1", "Loja 2", "Loja 3", "Loja 4"),
    vertical_spacing=0.2,
    horizontal_spacing=0.2,
    )

    fig_subplot.add_trace(go.Bar(x=dataframe1['Categoria do Produto'], y =dataframe1['Preço'],text=dataframe1['Preço']), row=1,col=1)
    fig_subplot.add_trace(go.Bar(x=dataframe2['Categoria do Produto'], y =dataframe2['Preço'],text=dataframe2['Preço']), row=2,col=1)
    fig_subplot.add_trace(go.Bar(x=dataframe3['Categoria do Produto'], y =dataframe3['Preço'],text=dataframe3['Preço']), row=1,col=2)
    fig_subplot.add_trace(go.Bar(x=dataframe4['Categoria do Produto'], y =dataframe4['Preço'],text=dataframe4['Preço']), row=2,col=2)
    fig_subplot.update_traces(texttemplate='R$ %{text:,.2f}',
                              textposition='outside',
                              textfont={
                                  'size': 114,         # Tamanho da fonte
                                  'family': "Arial",   # Família da fonte
                                  'color': "black",    # Cor do texto
                                  'weight': "bold"     # Negrito
                                                  },
                              cliponaxis=False,        # Permite que o texto ultrapasse os limites do gráfico
                              )
    fig_subplot.update_layout(
    height=900,
    width=1500,
    title_text="Subplots do Plotly"
)

    fig_subplot.show()

subplots(total_por_Categoria1,total_por_Categoria2,total_por_Categoria3,total_por_Categoria4)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %%
def avaliação(dataframe):
  return round(dataframe['Avaliação da compra'].mean(),2)

avaliação_loja1 = avaliação(loja_1)
avaliação_loja2 = avaliação(loja_2)
avaliação_loja3 = avaliação(loja_3)
avaliação_loja4 = avaliação(loja_4)

print(f'Avaliação das lojas:\nloja 1: {avaliação_loja1}\nloja 2: {avaliação_loja2}\nloja 3: {avaliação_loja3}\nloja 4: {avaliação_loja4}')

df_media_loja = {
    "Loja": ["Loja 1", "Loja 2", "Loja 3", "Loja 4"],
    "Média de Avaliação": [avaliação_loja1, avaliação_loja2, avaliação_loja3, avaliação_loja4]
}
df_media_loja = pd.DataFrame(df_media_loja)

fig_media_loja = px.bar(data_frame=df_media_loja,
             x="Loja",
             y='Média de Avaliação',
             title="Média de Avaliação por loja",
             color="Loja",
             text="Média de Avaliação")
fig_media_loja.update_layout(
    height=500,
    width=500
)
fig_media_loja.show()
# Out:
# Avaliação das lojas:
# loja 1: 3.98
# loja 2: 4.04
# loja 3: 4.05
# loja 4: 4.0
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %%
def Produtos_mais_menos_vendidos(dataframe):
  qtd_produtos_vendidos = dataframe.groupby('Produto')['Preço'].count().reset_index()
  qtd_produtos_vendidos = pd.DataFrame(qtd_produtos_vendidos)
  return qtd_produtos_vendidos

produtos_vendidos = Produtos_mais_menos_vendidos(loja_1)
fig_produtos_vendidos = px.bar(data_frame=produtos_vendidos,
             x="Produto",
             y='Preço',
             title="Produtos Mais Vendidos",
             color="Produto",
             text="Preço")
# removers axis
fig_produtos_vendidos.update_layout(showlegend=False)
fig_produtos_vendidos.update_traces(textfont={"weight":"bold"})
fig_produtos_vendidos.update_layout(
    height=600,
    width=1500
)
fig_produtos_vendidos.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
produtos_vendidos
# Out:
#                         Produto  Preço
# 0            Assistente virtual     40
# 1                       Bateria     53
# 2                     Bicicleta     54
# 3              Blocos de montar     56
# 4              Bola de basquete     55
# 5                 Bola de vôlei     42
# 6                   Boneca bebê     40
# 7         Cadeira de escritório     46
# 8                      Cama box     44
# 9                     Cama king     44
# 10     Carrinho controle remoto     52
# 11                 Celular ABXY     33
# 12             Celular Plus X42     49
# 13  Ciência de dados com python     39
# 14                 Copo térmico     54
# 15               Corda de pular     40
# 16              Cubo mágico 8x8     44
# 17                       Cômoda     56
# 18      Dashboards com Power BI     42
# 19               Dinossauro Rex     40
# 20                     Faqueiro     52
# 21                        Fogão     45
# 22               Fone de ouvido     50
# ...

# %% [markdown]
# # 5. Frete Médio por Loja

# %%
frete_medio_loja1 = round(loja_1['Frete'].mean())
frete_medio_loja2 = round(loja_2['Frete'].mean())
frete_medio_loja3 = round(loja_3['Frete'].mean())
frete_medio_loja4 = round(loja_4['Frete'].mean())

df_fretes = {
    "Lojas": ["Loja 1","Loja 2", "Loja 3", "Loja 4"],
    "Frete": [frete_medio_loja1, frete_medio_loja2, frete_medio_loja3, frete_medio_loja4]
}
df_fretes = pd.DataFrame(df_fretes)
df_fretes
# Out:
#     Lojas  Frete
# 0  Loja 1     35
# 1  Loja 2     34
# 2  Loja 3     33
# 3  Loja 4     31

# %%
fig_frete = px.bar(data_frame=df_fretes,
             x="Lojas",
             y='Frete',
             title="Frete Médio por Loja",
             color="Lojas",
             text="Frete")

fig_frete.update_traces(texttemplate='R$ %{text:,.2f}',
                        textposition='outside')
fig_frete.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
